# %%
from sklearn.datasets import make_blobs
import pandas as pd

# %%
#make blobs
n_class = 5
blobs = make_blobs(n_samples=1000, n_features=2, centers=n_class,random_state=0)
X,label = blobs
df = {"x":X[:,0],"y":X[:,1],"label":label}
df = pd.DataFrame(data=df)
df.to_csv("data.csv")

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:,0],X[:,1],c=label)

# %%
#build model
from keras import backend as K
from keras.layers import Activation
from keras.layers import Input, Lambda, Dense, Dropout, Convolution2D, MaxPooling2D, Flatten,Conv2D
from keras.models import Sequential, Model
from keras.optimizers import RMSprop,Adam,SGD
from keras.regularizers import l2
import tensorflow as tf
import tensorflow.keras as keras

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.python.keras.callbacks import TensorBoard

# %%
def build_model():
    model = Sequential()
    model.add(Dense(n_class,activation="softmax",input_shape=(2,),kernel_regularizer=l2(2e-4)))
        
    return model

# %%
model = build_model()

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 5)                 15
# =================================================================
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________

# %%
tensorboard = TensorBoard(log_dir="graph/multi_class/")
rms = tf.train.RMSPropOptimizer(0.01)
model.compile(loss=keras.losses.categorical_crossentropy
              , optimizer=rms
             ,metrics=["acc",keras.metrics.categorical_crossentropy])

# %%
# training

from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

y = to_categorical(list(label),n_class)

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=.25)
print(x_train.shape)
print(x_test.shape)
print(y.shape,y[0])
# Out:
# (750, 2)
# (250, 2)
# (1000, 5) [0. 0. 0. 1. 0.]

# %%
his = model.fit(x_train,y_train,epochs=50,validation_split=0.25,batch_size=32
               ,callbacks=[tensorboard,EarlyStopping(monitor='val_loss',patience=20)])
# Out:
# Train on 562 samples, validate on 188 samples
# Epoch 1/50
# 562/562 [==============================] - 1s 1ms/step - loss: 0.1771 - acc: 0.9520 - categorical_crossentropy: 0.1698 - val_loss: 0.2007 - val_acc: 0.9255 - val_categorical_crossentropy: 0.1934
# Epoch 2/50
# 562/562 [==============================] - 0s 667us/step - loss: 0.1755 - acc: 0.9537 - categorical_crossentropy: 0.1682 - val_loss: 0.2008 - val_acc: 0.9255 - val_categorical_crossentropy: 0.1934
# Epoch 3/50
# 562/562 [==============================] - 0s 669us/step - loss: 0.1746 - acc: 0.9502 - categorical_crossentropy: 0.1671 - val_loss: 0.1985 - val_acc: 0.9255 - val_categorical_crossentropy: 0.1910
# Epoch 4/50
# 562/562 [==============================] - 0s 671us/step - loss: 0.1757 - acc: 0.9537 - categorical_crossentropy: 0.1682 - val_loss: 0.1974 - val_acc: 0.9255 - val_categorical_crossentropy: 0.1898
# Epoch 5/50
# 562/562 [==============================] - 0s 667us/step - loss: 0.1745 - acc: 0.9466 - categorical_crossentropy: 0.1669 - val_loss: 0.1986 - val_acc: 0.9255 - val_categorical_crossentropy: 0.1909
# Epoch 6/50
# 562/562 [==============================] - 0s 676us/step - loss: 0.1739 - acc: 0.9466 - categorical_crossentropy: 0.1661 - val_loss: 0.1960 - val_acc: 0.9255 - val_categorical_crossentropy: 0.1883
# Epoch 7/50
# 562/562 [==============================] - 0s 667us/step - loss: 0.1734 - acc: 0.9502 - categorical_crossentropy: 0.1657 - val_loss: 0.1967 - val_acc: 0.9255 - val_categorical_crossentropy: 0.1890
# Epoch 8/50
# 562/562 [==============================] - 0s 667us/step - loss: 0.1730 - acc: 0.9520 - categorical_crossentropy: 0.1652 - val_loss: 0.1960 - val_acc: 0.9255 - val_categorical_crossentropy: 0.1882
# Epoch 9/50
# 562/562 [==============================] - 0s 667us/step - loss: 0.1722 - acc: 0.9520 - categorical_crossentropy: 0.1644 - val_loss: 0.1960 - val_acc: 0.9255 - val_categorical_crossentropy: 0.
- val_acc: 0.9255 - val_categorical_crossentropy: 0.1800
# Epoch 45/50
# 562/562 [==============================] - 0s 683us/step - loss: 0.1630 - acc: 0.9520 - categorical_crossentropy: 0.1541 - val_loss: 0.1886 - val_acc: 0.9255 - val_categorical_crossentropy: 0.1798
# Epoch 46/50
# 562/562 [==============================] - 0s 838us/step - loss: 0.1623 - acc: 0.9520 - categorical_crossentropy: 0.1534 - val_loss: 0.1877 - val_acc: 0.9255 - val_categorical_crossentropy: 0.1789
# Epoch 47/50
# 562/562 [==============================] - 0s 673us/step - loss: 0.1644 - acc: 0.9484 - categorical_crossentropy: 0.1556 - val_loss: 0.1907 - val_acc: 0.9309 - val_categorical_crossentropy: 0.1819
# Epoch 48/50
# 562/562 [==============================] - 0s 673us/step - loss: 0.1632 - acc: 0.9502 - categorical_crossentropy: 0.1543 - val_loss: 0.1872 - val_acc: 0.9255 - val_categorical_crossentropy: 0.1783
# Epoch 49/50
# 562/562 [==============================] - 0s 673us/step - loss: 0.1630 - acc: 0.9537 - categorical_crossentropy: 0.1541 - val_loss: 0.1877 - val_acc: 0.9309 - val_categorical_crossentropy: 0.1788
# Epoch 50/50
# 562/562 [==============================] - 0s 669us/step - loss: 0.1611 - acc: 0.9502 - categorical_crossentropy: 0.1522 - val_loss: 0.1882 - val_acc: 0.9309 - val_categorical_crossentropy: 0.1794

# %%
# plot history training
loss = his.history["loss"]
val_loss = his.history["val_loss"]

fig = plt.figure()
plt.plot(loss,"r-",label="loss")
plt.plot(val_loss,"b-",label="val_loss")
plt.legend()
plt.savefig("training_loss_multi_class.png")

# %%
model.evaluate(x_test,y_test)
# Out:
# 250/250 [==============================] - 0s 28us/step
# [0.14515318477153777, 0.9440000004768372]

# %%
# pred = model.predict(x_test)
# pred[pred<0.5] = 0
# pred[pred>=0.5] = 1

# %%
import numpy as np
import sklearn.metrics

y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred,axis=1)
y_test = np.argmax(y_test,axis=1)

sklearn.metrics.confusion_matrix(y_pred,y_test)
# Out:
# array([[53,  0,  0,  0,  0],
#        [ 0, 48,  0,  0,  1],
#        [ 0,  0, 49,  0,  8],
#        [ 0,  0,  0, 44,  0],
#        [ 0,  1,  4,  0, 42]], dtype=int64)

# %%
model.get_weights()
# Out:
# [array([[ 0.4475782 , -1.0676111 , -0.9566817 ,  0.22296132, -0.38094884],
#         [-1.177028  ,  1.552827  , -1.40554   ,  0.7973408 , -0.4100722 ]],
#        dtype=float32),
#  array([-0.27720302, -1.2812322 , -1.8540028 , -0.0664695 ,  2.989653  ],
#        dtype=float32)]

# %%
fig = plt.figure()
for k in range(10):
    x = x_test[k]
    x = np.expand_dims(x,axis=0)

    colors = ["b","g","r","pink","brown"] # blue : 0 , green : 1 , red : 2
    for i in range(n_class):
        xx = X[label==i]
        plt.scatter(xx[:,0],xx[:,1],c=colors[i],label="class %d"%i)
        plt.title("class %d"%model.predict(x).argmax())
        
    plt.scatter(x[:,0],x[:,1],c="y",s=100)
    plt.legend()
    plt.pause(0.1)
    
plt.show()

# %%
14/250
# Out:
# 0.056
